# %% [markdown]
# ## YouTube Trending Project
# * ### Data Cleaning and Curation
#
# ### Table of Contents:
# * 1.Exploratory Data Analysis
# * 2.Data Cleaning
#     * 2.1 Preprocessing Data
#         * 2.1.1 Drop Duplicate Rows
#         * 2.1.2 Drop Columns
#         * 2.1.3 Handling Missing Data
#     * 2.2 Post-Processed Data
#         * 2.2.1 Column Information
#         * 2.2.2 Exporting Curated Data
#     * 2.3 Export Cleaned Data w/ All Columns
# * 3.Modeling

# %% [markdown]
# ### 2. Data Cleaning
# ##### Loading Data and Libraries

# %%
import helpers
import pandas as pd
import numpy as np
import datetime as dt

# Encoding and Data Split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# Plotting Modules
import matplotlib.pyplot as plt

# Reading the stitched data
trend_data = helpers.load_df("Data/US_Data.csv")

df = trend_data.copy()
df.head()
# Out:
#       video_id                                              title  \
# 0  bPiofmZGb8o  Second 2020 Presidential Debate between Donald...
# 1  tcYodQoapMg         Ariana Grande - positions (official video)
# 2  np9Ub1LilKU         Jack Harlow - Tyler Herro [Official Video]
# 3  5S4bm3bAt9Y                SURPRISING BEST FRIEND WITH BORAT!!
# 4  GuEkHIgR46k    Bryson Tiller - Always Forever (Official Video)
#
#             publishedAt                 channelId      channelTitle  \
# 0  2020-10-23T02:49:33Z  UCb--64Gl51jIEVE-GLDAVTg            C-SPAN
# 1  2020-10-23T04:00:10Z  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 2  2020-10-22T19:00:14Z  UC6vZl7Qj7JglLDmN_7Or-ZQ       Jack Harlow
# 3  2020-10-21T19:56:24Z  UCef29bYGgUSoJjVkqhcAPkw  David Dobrik Too
# 4  2020-10-22T16:00:08Z  UCwhe-6skwaZxLomc-U6Wy1w  BrysonTillerVEVO
#
#    categoryId trending_date  \
# 0          25      20.23.10
# 1          10      20.23.10
# 2          10      20.23.10
# 3          22      20.23.10
# 4          10      20.23.10
#
#                                                 tags  view_count    likes  \
# 0  C-SPAN|CSPAN|2020|Donald Trump|Republican|Whit...     6641600    94601
# 1  ariana grande positions|positions ariana grand...     7516529  1485130
# 2  jack harlow|jack rapper|harlow rapper|private ...     1499338   153028
# 3                                             [none]     5320147   596894
# 4  Bryson Tiller 2020|Bryson Tiller Serenity|Brys...      862087    82059
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      6209          59293  https://i.ytimg.com/vi/bPiofmZGb8o/default.jpg
# 1     10810         140549  https://i.ytimg.com/vi/tcYodQoapMg/default.jpg
# 2      2006          11013  https://i.ytimg.com/vi/np9Ub1LilKU/default.jpg
# 3      7044          33648  https://i.ytimg.com/vi/5S4bm3bAt9Y/default.jpg
# 4       657           4459  https://i.ytimg.com/vi/GuEkHIgR46k/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description  duration country
# 0  President Donald Trump and former Vice Preside...  1H59M15S      US
# 1  The official “positions” music video by Ariana...     2M58S      US
# 2  Jack Harlow - Tyler HerroListen now: https://J...        3M      US
# 3  Thank you Borat for coming over!! I like youWa...     5M55S      US
# 4  A N N I V E R S A R Y OUT NOW!Stream/Download:...     2M59S      US

# %% [markdown]
# ##### Checking shape of data frame and applying feature engineering

# %%
np.shape(df)
# Out:
#       ...  dislikes_log  comment_log new_date_published  new_date_trending  \
# 0     ...      8.733755    10.990247         2020-10-23         2020-10-23
# 1     ...      9.288227    11.853311         2020-10-23         2020-10-23
# 2     ...      7.603898     9.306832         2020-10-22         2020-10-23
# 3     ...      8.859931    10.423709         2020-10-21         2020-10-23
# 4     ...      6.487684     8.402680         2020-10-22         2020-10-23
# ...   ...           ...          ...                ...                ...
# 2795  ...      7.848543    10.174354         2021-01-11         2021-01-20
# 2796  ...      5.545177     7.561122         2021-01-12         2021-01-20
# 2797  ...      9.433484    10.922100         2021-01-11         2021-01-20
# 2798  ...      8.436850     8.801921         2021-01-12         2021-01-20
# 2799  ...      5.010635     4.969813         2021-01-13         2021-01-20
#
#       days_lapse durationHr durationMin durationSec  titleLength  tagCount
# 0            0.0          1          59          15           66        12
# 1            0.0          0           2          58           42        22
# 2            1.0          0           3           0           42        26
# 3            2.0          0           5          55           35         0
# 4            1.0          0           2          59           47        22
# ...          ...        ...         ...         ...          ...       ...
# 2795         9.0          0          10           1           20        17
# 2796         8.0          0           4           3           63        19
# 2797         9.0          0           5          41           64        11
# 2798         8.0          0           1          25           57        32
# 2799         7.0          6          10          57           74        10
#
# [2736 rows x 31 columns]

# %%
# Must drop duplicate video observations collected over multiple days
df[df.video_id == 'tcYodQoapMg']
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:822: RuntimeWarning: divide by zero encountered in double_scalars
#   norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:850: RuntimeWarning: invalid value encountered in multiply
#   f_indices = _unsigned_subtract(tmp_a, first_edge) * norm
#          video_id                                       title  \
# 1     tcYodQoapMg  Ariana Grande - positions (official video)
# 201   tcYodQoapMg  Ariana Grande - positions (official video)
# 409   tcYodQoapMg  Ariana Grande - positions (official video)
# 635   tcYodQoapMg  Ariana Grande - positions (official video)
# 865   tcYodQoapMg  Ariana Grande - positions (official video)
# 1095  tcYodQoapMg  Ariana Grande - positions (official video)
#
#              publishedAt                 channelId      channelTitle  \
# 1    2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 201  2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 409  2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 635  2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 865  2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 1095 2020-10-23 04:00:10  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
#
#       categoryId trending_date  \
# 1             10    2020-10-23
# 201           10    2020-10-24
# 409           10    2020-10-25
# 635           10    2020-10-26
# 865           10    2020-10-27
# 1095          10    2020-10-28
#
#                                                    tags  view_count    likes  \
# 1     ariana grande positions|positions ariana grand...     7516529  1485130
# 201   ariana grande positions|positions ariana grand...    25585327  2512982
# 409   ariana grande positions|positions ariana grand...    30951274  2669799
# 635   ariana grande positions|positions ariana grand...    35639675  2805619
# 865   ariana grande positions|positions ariana grand...    39680390  2934736
# 1095  ariana grande positions|positions ariana grand...    43246851  3033311
#
#       ...  dislikes_log  comment_log new_date_published  new_date_trending  \
# 1     ...      9.288227    11.853311         2020-10-23         2020-10-23
# 201   ...     10.447061    12.198529         2020-10-23         2020-10-24
# 409   ...     10.623934    12.244918         2020-10-23         2020-10-25
# 635   ...     10.751328    12.284408         2020-10-23         2020-10-26
# 865   ...     10.840796    12.309869         2020-10-23         2020-10-27
# 1095  ...     10.902703    12.331290         2020-10-23         2020-10-28
#
#       days_lapse durationHr durationMin durationSec  titleLength  tagCount
# 1            0.0          0           2          58           42        22
# 201          1.0          0           2          58           42        22
# 409          2.0          0           2          58           42        22
# 635          3.0          0           2          58           42        22
# 865          4.0          0           2          58           42        22
# 1095         5.0          0           2          58           42        22
#
# [6 rows x 31 columns]

# %% [markdown]
# ### 2.1 Preprocessing Data
# * ##### 2.1.1 Drop Duplicate Rows
# * ##### 2.1.2 Drop Columns - Unnecessary or low correlation
# * ##### 2.1.3 Handling Missing Data - Drop rows with missing values

# %%
helpers.preprocess(df)
# Out:
#       categoryId  likeRatio  likes_log  views_log  dislikes_log  comment_log  \
# 0             25   0.876818  11.457423  15.708863      8.733755    10.990247
# 1             10   0.985548  14.211013  15.832615      9.288227    11.853311
# 2             10   0.974122  11.938376  14.220534      7.603898     9.306832
# 3             22   0.976673  13.299495  15.487011      8.859931    10.423709
# 4             10   0.984114  11.315194  13.667111      6.487684     8.402680
# ...          ...        ...        ...        ...           ...          ...
# 2795          22   0.978887  12.388952  14.933087      7.848543    10.174354
# 2796          10   0.983655  10.343966  12.728645      5.545177     7.561122
# 2797          10   0.958661  13.291704  16.079583      9.433484    10.922100
# 2798          20   0.829155  10.807706  13.822260      8.436850     8.801921
# 2799          28   0.957800   8.847791  12.871561      5.010635     4.969813
#
#       days_lapse  durationHr  durationMin  durationSec  titleLength  tagCount
# 0            0.0           1           59           15           66        12
# 1            0.0           0            2           58           42        22
# 2            1.0           0            3            0           42        26
# 3            2.0           0            5           55           35         0
# 4            1.0           0            2           59           47        22
# ...          ...         ...          ...          ...          ...       ...
# 2795         9.0           0           10            1           20        17
# 2796         8.0           0            4            3           63        19
# 2797         9.0           0            5           41           64        11
# 2798         8.0           0            1           25           57        32
# 2799         7.0           6           10           57           74        10
#
# [2736 rows x 12 columns]

# %% [markdown]
# ### 2.2 Post-Processed Data
# * ##### 2.2.1 Column Information
# * ##### 2.2.2 Exporting Curated Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2736 entries, 0 to 2799
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   categoryId    2736 non-null   int64
#  1   likeRatio     2736 non-null   float64
#  2   likes_log     2736 non-null   float64
#  3   views_log     2736 non-null   float64
#  4   dislikes_log  2736 non-null   float64
#  5   comment_log   2736 non-null   float64
#  6   days_lapse    2736 non-null   float64
#  7   durationHr    2736 non-null   int64
#  8   durationMin   2736 non-null   int64
#  9   durationSec   2736 non-null   int64
#  10  titleLength   2736 non-null   int64
#  11  tagCount      2736 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 342.4 KB

# %%
df.to_csv("Data/Curated_US_Data.csv", index=False)

# %% [markdown]
# ### 2.3 Export Cleaned Data w/ All Columns
#
# Export data that has been cleaned of duplicates and missing values, but no dropped columns

# %%
df = trend_data.copy()

helpers.featureEng(df)

df = df.drop_duplicates(subset=['video_id'], keep='last', ignore_index=True)

# Drop missing values
df.dropna()

df.to_csv("Data/FeatureEng_US_Data.csv", index=False)
