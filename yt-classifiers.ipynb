# %%
import pandas as pd
import numpy as np
import datetime as dt

# Encoding and Data Split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
#import category_encoders as ce

# Plotting Modules
import matplotlib.pyplot as plt

# Reading the stitched data
trend_data = pd.read_csv("../YouTube-Trending/Data/INT_10.23-27.20.csv")
# Set seed for reproducibility
np.random.seed(0)

df = trend_data.copy()
df.head()
# Out:
#       video_id                                              title  \
# 0  bPiofmZGb8o  Second 2020 Presidential Debate between Donald...
# 1  tcYodQoapMg         Ariana Grande - positions (official video)
# 2  np9Ub1LilKU         Jack Harlow - Tyler Herro [Official Video]
# 3  5S4bm3bAt9Y                SURPRISING BEST FRIEND WITH BORAT!!
# 4  GuEkHIgR46k    Bryson Tiller - Always Forever (Official Video)
#
#             publishedAt                 channelId      channelTitle  \
# 0  2020-10-23T02:49:33Z  UCb--64Gl51jIEVE-GLDAVTg            C-SPAN
# 1  2020-10-23T04:00:10Z  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 2  2020-10-22T19:00:14Z  UC6vZl7Qj7JglLDmN_7Or-ZQ       Jack Harlow
# 3  2020-10-21T19:56:24Z  UCef29bYGgUSoJjVkqhcAPkw  David Dobrik Too
# 4  2020-10-22T16:00:08Z  UCwhe-6skwaZxLomc-U6Wy1w  BrysonTillerVEVO
#
#    categoryId trending_date  \
# 0          25      20.23.10
# 1          10      20.23.10
# 2          10      20.23.10
# 3          22      20.23.10
# 4          10      20.23.10
#
#                                                 tags  view_count    likes  \
# 0  C-SPAN|CSPAN|2020|Donald Trump|Republican|Whit...     6641600    94601
# 1  ariana grande positions|positions ariana grand...     7516529  1485130
# 2  jack harlow|jack rapper|harlow rapper|private ...     1499338   153028
# 3                                             [none]     5320147   596894
# 4  Bryson Tiller 2020|Bryson Tiller Serenity|Brys...      862087    82059
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      6209          59293  https://i.ytimg.com/vi/bPiofmZGb8o/default.jpg
# 1     10810         140549  https://i.ytimg.com/vi/tcYodQoapMg/default.jpg
# 2      2006          11013  https://i.ytimg.com/vi/np9Ub1LilKU/default.jpg
# 3      7044          33648  https://i.ytimg.com/vi/5S4bm3bAt9Y/default.jpg
# 4       657           4459  https://i.ytimg.com/vi/GuEkHIgR46k/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description  duration country
# 0  President Donald Trump and former Vice Preside...  1H59M15S      US
# 1  The official “positions” music video by Ariana...     2M58S      US
# 2  Jack Harlow - Tyler HerroListen now: https://J...        3M      US
# 3  Thank you Borat for coming over!! I like youWa...     5M55S      US
# 4  A N N I V E R S A R Y OUT NOW!Stream/Download:...     2M59S      US

# %%
# Dropping unneeded columns
df.drop(columns=['channelTitle', 'video_id', 'title', 'description',
'channelTitle', 'tags', 'thumbnail_link', 'comments_disabled',
'ratings_disabled'], axis=0, inplace=True)

df.head()
# Out:
#             publishedAt                 channelId  categoryId trending_date  \
# 0  2020-10-23T02:49:33Z  UCb--64Gl51jIEVE-GLDAVTg          25      20.23.10
# 1  2020-10-23T04:00:10Z  UC0VOyT2OCBKdQhF3BAbZ-1g          10      20.23.10
# 2  2020-10-22T19:00:14Z  UC6vZl7Qj7JglLDmN_7Or-ZQ          10      20.23.10
# 3  2020-10-21T19:56:24Z  UCef29bYGgUSoJjVkqhcAPkw          22      20.23.10
# 4  2020-10-22T16:00:08Z  UCwhe-6skwaZxLomc-U6Wy1w          10      20.23.10
#
#    view_count    likes  dislikes  comment_count  duration country
# 0     6641600    94601      6209          59293  1H59M15S      US
# 1     7516529  1485130     10810         140549     2M58S      US
# 2     1499338   153028      2006          11013        3M      US
# 3     5320147   596894      7044          33648     5M55S      US
# 4      862087    82059       657           4459     2M59S      US

# %%
# Changing the publishedAt and trending_date type from string to datetime type
df['publishedAt'] = pd.to_datetime(df['publishedAt'])
df['trending_date'] = pd.to_datetime(df['trending_date'], format="%y.%d.%m")

df.head()

# %% [markdown]
# ### One Hot Encoding Trending Date
# Mapping each date to a vector consisting of 0s and 1s
# that denote the absence or presence of the feature

# %%
X = trend_data.iloc[:,0:-1]
y = trend_data['country']
X.head()
# Out:
#       video_id                                              title  \
# 0  bPiofmZGb8o  Second 2020 Presidential Debate between Donald...
# 1  tcYodQoapMg         Ariana Grande - positions (official video)
# 2  np9Ub1LilKU         Jack Harlow - Tyler Herro [Official Video]
# 3  5S4bm3bAt9Y                SURPRISING BEST FRIEND WITH BORAT!!
# 4  GuEkHIgR46k    Bryson Tiller - Always Forever (Official Video)
#
#             publishedAt                 channelId      channelTitle  \
# 0  2020-10-23T02:49:33Z  UCb--64Gl51jIEVE-GLDAVTg            C-SPAN
# 1  2020-10-23T04:00:10Z  UC0VOyT2OCBKdQhF3BAbZ-1g  ArianaGrandeVevo
# 2  2020-10-22T19:00:14Z  UC6vZl7Qj7JglLDmN_7Or-ZQ       Jack Harlow
# 3  2020-10-21T19:56:24Z  UCef29bYGgUSoJjVkqhcAPkw  David Dobrik Too
# 4  2020-10-22T16:00:08Z  UCwhe-6skwaZxLomc-U6Wy1w  BrysonTillerVEVO
#
#    categoryId trending_date  \
# 0          25      20.23.10
# 1          10      20.23.10
# 2          10      20.23.10
# 3          22      20.23.10
# 4          10      20.23.10
#
#                                                 tags  view_count    likes  \
# 0  C-SPAN|CSPAN|2020|Donald Trump|Republican|Whit...     6641600    94601
# 1  ariana grande positions|positions ariana grand...     7516529  1485130
# 2  jack harlow|jack rapper|harlow rapper|private ...     1499338   153028
# 3                                             [none]     5320147   596894
# 4  Bryson Tiller 2020|Bryson Tiller Serenity|Brys...      862087    82059
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      6209          59293  https://i.ytimg.com/vi/bPiofmZGb8o/default.jpg
# 1     10810         140549  https://i.ytimg.com/vi/tcYodQoapMg/default.jpg
# 2      2006          11013  https://i.ytimg.com/vi/np9Ub1LilKU/default.jpg
# 3      7044          33648  https://i.ytimg.com/vi/5S4bm3bAt9Y/default.jpg
# 4       657           4459  https://i.ytimg.com/vi/GuEkHIgR46k/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description  duration
# 0  President Donald Trump and former Vice Preside...  1H59M15S
# 1  The official “positions” music video by Ariana...     2M58S
# 2  Jack Harlow - Tyler HerroListen now: https://J...        3M
# 3  Thank you Borat for coming over!! I like youWa...     5M55S
# 4  A N N I V E R S A R Y OUT NOW!Stream/Download:...     2M59S

# %%
ce_one_hot = ce.OneHotEncoder(cols= ['trending_date'])
newX = ce_one_hot.fit_transform(X, y)
newX.head ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f9de8d8e644e> in <module>
# ----> 1 ce_one_hot = ce.OneHotEncoder(cols= ['trending_date'])
#       2 newX = ce_one_hot.fit_transform(X, y)
#       3 newX.head ()
#
# NameError: name 'ce' is not defined
